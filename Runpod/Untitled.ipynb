# %%
# !pip install runpod
# Out:
# ...
#   Obtaining dependency information for runpod from https://files.pythonhosted.org/packages/e4/65/cb056a1f25c4a9c12515da59b630faa923e9a7b5ea3a9d71aad3b0bce9f2/runpod-1.6.2-py3-none-any.whl.metadata
# ...
#   Obtaining dependency information for aiohttp[speedups]==3.9.3 from https://files.pythonhosted.org/packages/d3/b0/efb74d5f92a460c774e0254b3109c2d00fd3a1553f98363abb2b25cac9a3/aiohttp-3.9.3-cp311-cp311-macosx_11_0_arm64.whl.metadata
#   Using cached aiohttp-3.9.3-cp311-cp311-macosx_11_0_arm64.whl.metadata (7.4 kB)
# ...
#   Obtaining dependency information for aiohttp-retry>=2.8.3 from https://files.pythonhosted.org/packages/57/57/af573003eca6248a5cbc538fc46bea5b249c2ac86f27140b0a621bcd3fde/aiohttp_retry-2.8.3-py3-none-any.whl.metadata
# ...
#   Obtaining dependency information for backoff>=2.2.1 from https://files.pythonhosted.org/packages/df/73/b6e24bd22e6720ca8ee9a85a0c4a2971af8497d8f3193fa05390cbd46e09/backoff-2.2.1-py3-none-any.whl.metadata
# ...

# %%
token = "EBBS9HZ1K24R4Y52YLYUHHYKNLZFLD6TVC1Z56ZS"
endpoint = "https://api.runpod.ai/v2/stable-diffusion-v1/"

import runpod
import os

# %%
runpod.api_key = token
endpoints = runpod.get_endpoints()
print(endpoints)
# Out:
# [{'aiKey': 'T4C4QKD86QFX9FDK2QYZEO8VVLUJZ80SEQHBNROZ', 'gpuIds': 'ADA_24', 'id': '8jhc44hl7f6kc9', 'idleTimeout': 10, 'name': 'stable_beluga_2 -fb', 'networkVolumeId': None, 'locations': None, 'scalerType': 'QUEUE_DELAY', 'scalerValue': 4, 'templateId': 'f02dqd84vm', 'type': 'QB', 'userId': 'user_2UMfsvfneK8D6RMowhNMf14KgJ4', 'version': 1, 'workersMax': 1, 'workersMin': 0, 'workersStandby': 1, 'gpuCount': 1, 'env': None, 'createdAt': '2023-09-08T01:28:51.958Z', 'networkVolume': None}]
