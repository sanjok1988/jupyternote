# %%
# Your data
data = [
    {'skill': 'Business English', 'level': 'Level 2'},
    {'skill': 'RS Business English', 'level': 'Level 0'},
    {'skill': 'Business English', 'level': 'Level 3'},
    {'skill': 'Business English', 'level': 'Level 5'},
    {'skill': 'Business English', 'level': 'Level 0'},
    {'skill': 'Business English', 'level': 'Level 6'},
    {'skill': 'Business English', 'level': 'Level 4'},
    {'skill': 'Business English', 'level': 'Level 1'},
    {'skill': 'General English', 'level': 'Level 2'},
    {'skill': 'General English', 'level': 'Level 3'},
    {'skill': 'General English', 'level': 'Level 1'},
    {'skill': 'General English', 'level': 'Level 4'},
    {'skill': 'General English', 'level': 'Level 5'},
    {'skill': 'General English', 'level': 'Level 6'},
    {'skill': 'General English', 'level': 'Level 0'},
    {'skill': 'General English', 'level': 'Level 7'},
    {'skill': 'General English', 'level': 'Level 8'},
    {'skill': 'General English', 'level': 'Level 9'},
    {'skill': 'General English', 'level': 'Level 10'},
    {'skill': 'RS English', 'level': 'Level 8'},
    {'skill': 'RS English', 'level': 'Level 0'},
    {'skill': 'RS English', 'level': 'Level 7'},
    {'skill': 'RS English', 'level': 'Level 5'},
    {'skill': 'RS English', 'level': 'Level 3'},
    {'skill': 'RS English', 'level': 'Level 6'}
]

# Provided list
provided_list = [
    'English Advantage - Starter Book',
    'English Advantage - Starter Book 1',
    'English Advantage - Novice Book 2',
    'English Advantage - Novice Book 3',
    'English Advantage - Intermediate Book 4',
    'English Advantage - Intermediate Book 5',
    'English Advantage - Intermediate Book 6',
    'English Advantage - Pre-Advanced Book 7',
    'English Advantage - Pre-Advanced Book 8',
    'English Advantage - Pre-Advanced Book 9',
    'English Advantage - Pre-Advanced Book 10',
    'English Advantage - Foundations',
    'English Advantage - Foundations Demo',
    'Business Edge - Book 1 (A1)',
    'Business Edge - Book 2 (A2)',
    'Business Edge - Book 3 (A2)',
    'Business Edge - Book 4 (B1)',
    'Business Edge - Book 5 (B1)',
    'Business Edge - Book 6 (B1)',
    'Business Edge - Foundations'
]

# Combine the provided list and data into a dictionary with keys from the provided list and values from data
combined_dict = {}

for item in data:
    key = f"{item['skill']} - {item['level']}"
    for provided_key in provided_list:
        print(provided_key)
        if provided_key in key:
            combined_dict.setdefault(provided_key, []).append(item)

# Print the combined dictionary
for key, value in combined_dict.items():
    print(key, ':', value)
# Out:
# English Advantage - Starter Book
# English Advantage - Starter Book 1
# English Advantage - Novice Book 2
# English Advantage - Novice Book 3
# English Advantage - Intermediate Book 4
# English Advantage - Intermediate Book 5
# English Advantage - Intermediate Book 6
# English Advantage - Pre-Advanced Book 7
# English Advantage - Pre-Advanced Book 8
# English Advantage - Pre-Advanced Book 9
# English Advantage - Pre-Advanced Book 10
# English Advantage - Foundations
# English Advantage - Foundations Demo
# Business Edge - Book 1 (A1)
# Business Edge - Book 2 (A2)
# Business Edge - Book 3 (A2)
# Business Edge - Book 4 (B1)
# Business Edge - Book 5 (B1)
# Business Edge - Book 6 (B1)
# Business Edge - Foundations
# English Advantage - Starter Book
# English Advantage - Starter Book 1
# English Advantage - Novice Book 2
# English Advantage - Novice Book 3
# English Advantage - Intermediate Book 4
# English Advantage - Intermediate Book 5
# English Advantage - Intermediate Book 6
# ...
